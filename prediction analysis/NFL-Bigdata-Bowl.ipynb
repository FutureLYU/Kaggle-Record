# %% [markdown]
# ## NFL Big Data Bowl

# %% [markdown]
# **Content**
# 1. [Importing Libraries](#1)
# 1. [Loading Dataset](#2)
# 1. [Feature Preprocess](#3)
# 1. [Feature Selection](#4)
# 1. [NN Model and CV](#5)
# 1. [Submission](#6)

# %% [markdown]
# <a id="1"></a> <br>
# # Importing Libraries

# %%
# PACKAGES
import os
import time
import warnings
from kaggle.competitions import nflrush

import re
import codecs
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

import plotly as py
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

from sklearn.metrics.pairwise import euclidean_distances
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

#import keras.backend as K
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input, Flatten, concatenate, Dropout, Lambda, BatchNormalization,GaussianNoise,LSTM
from tensorflow.keras.models import Model
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
# !pip install -U keras-tuner
# # from tensorflow import keras
# # from tensorflow.keras import layers
# #import tensorflow.python as tensorflow
# from kerastuner.tuners import RandomSearch
# #from kerastuner.engine.hypermodel import HyperModel
# #from kerastuner.engine.hyperparameters import HyperParameters
# import kerastuner as kt

# SETTINGS
os.environ['CUDA_VISIBLE_DEVICES'] = "1"
init_notebook_mode(connected=True)
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 150)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# <a id="2"></a> <br>
# # Loading Dataset

# %%
# DATA
origin_df = pd.read_csv('../input/nfl-big-data-bowl-2020/train.csv', dtype={'WindSpeed': 'object'})
train_df = origin_df.copy()
outcomes = train_df[['GameId','PlayId','Yards']].drop_duplicates()
train_df.head()
# Out:
#        GameId          PlayId  Team      X      Y     S     A   Dis  \
# 0  2017090700  20170907000118  away  73.91  34.84  1.69  1.13  0.40
# 1  2017090700  20170907000118  away  74.67  32.64  0.42  1.35  0.01
# 2  2017090700  20170907000118  away  74.00  33.20  1.22  0.59  0.31
# 3  2017090700  20170907000118  away  71.46  27.70  0.42  0.54  0.02
# 4  2017090700  20170907000118  away  69.32  35.42  1.82  2.43  0.16
#
#    Orientation     Dir    NflId      DisplayName  JerseyNumber  Season  \
# 0        81.99  177.18   496723       Eric Berry            29    2017
# 1        27.61  198.70  2495116     Allen Bailey            97    2017
# 2         3.01  202.73  2495493   Justin Houston            50    2017
# 3       359.77  105.64  2506353  Derrick Johnson            56    2017
# 4        12.63  164.31  2530794       Ron Parker            38    2017
#
#    YardLine  Quarter GameClock PossessionTeam  Down  Distance FieldPosition  \
# 0        35        1  14:14:00             NE     3         2            NE
# 1        35        1  14:14:00             NE     3         2            NE
# 2        35        1  14:14:00             NE     3         2            NE
# 3        35        1  14:14:00             NE     3         2            NE
# 4        35        1  14:14:00             NE     3         2            NE
#
#    HomeScoreBeforePlay  VisitorScoreBeforePlay  NflIdRusher OffenseFormation  \
# 0                    0                       0      2543773          SHOTGUN
# 1                    0                       0      2543773          SHOTGUN
# 2                    0                       0      2543773          SHOTGUN
# 3                    0                       0      2543773          SHOTGUN
# 4                    0                       0      2543773          SHOTGUN
#
#    OffensePersonnel  DefendersInTheBox  DefensePersonnel PlayDirection  \
# 0  1 RB, 1 TE, 3 WR                6.0  2 DL, 3 LB, 6 DB          left
# 1  1 RB, 1 TE, 3 WR                6.0  2 DL, 3 LB, 6 DB          left
# 2  1 RB, 1 TE, 3 WR                6.0  2 DL, 3 LB, 6 DB          left
# 3  1 RB, 1 TE, 3 WR                6.0  2 DL, 3 LB, 6 DB          left
# 4  1 RB, 1 TE, 3 WR                6.0  2 DL, 3 LB, 6 DB          left
#
#                 TimeHandoff                  TimeSnap  Yards PlayerHeight  \
# 0  2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8          6-0
# 1  2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8          6-3
# 2  2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8          6-3
# 3  2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8          6-3
# 4  2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8          6-0
#
#    PlayerWeight PlayerBirthDate PlayerCollegeName Position HomeTeamAbbr  \
# 0           212      12/29/1988         Tennessee       SS           NE
# 1           288      03/25/1989             Miami       DE           NE
# 2           270      01/21/1989           Georgia       DE           NE
# 3           245      11/22/1982             Texas      ILB           NE
# 4           206      08/17/1987          Newberry       FS           NE
#
#   VisitorTeamAbbr  Week           Stadium        Location StadiumType  \
# 0              KC     1  Gillette Stadium  Foxborough, MA     Outdoor
# 1              KC     1  Gillette Stadium  Foxborough, MA     Outdoor
# 2              KC     1  Gillette Stadium  Foxborough, MA     Outdoor
# 3              KC     1  Gillette Stadium  Foxborough, MA     Outdoor
# 4              KC     1  Gillette Stadium  Foxborough, MA     Outdoor
#
#          Turf     GameWeather  Temperature  Humidity WindSpeed WindDirection
# 0  Field Turf  Clear and warm         63.0      77.0         8            SW
# 1  Field Turf  Clear and warm         63.0      77.0         8            SW
# 2  Field Turf  Clear and warm         63.0      77.0         8            SW
# 3  Field Turf  Clear and warm         63.0      77.0         8            SW
# 4  Field Turf  Clear and warm         63.0      77.0         8            SW

# %% [markdown]
# <a id="3"></a> <br>
# # Feature Preprocess

# %%
#
# FEATURE UTILITY FUNCTION
#

# WindSpeed
def strToFloat(x):
    try:
        return float(x)
    except:
        # 0 or -1
        return -1

# Weather
def mapWeather(txt):
    ans = 1
    if pd.isna(txt):
        return 0
    if 'partly' in txt:
        ans *= 0.5
    if 'climate controlled' in txt or 'indoor' in txt or 'controlled climate' in txt:
        return ans*3
    if 'sunny' in txt or 'sun' in txt:
        return ans*2
    if 'clear' in txt:
        return ans
    if 'cloudy' in txt:
        return -ans
    if 'rain' in txt or 'rainy' in txt:
        return -2*ans
    if 'snow' in txt: # cold
        return -3*ans
    return 0

# Personnel Offense/Defense
def offensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0, 'QB' : 0, 'RB' : 0, 'TE' : 0, 'WR' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def DefensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

# Orientation (why to category / 15?10?)
def orientationToCat(x):
    try:
        return str(int(np.clip(x, 0, 360 - 1)/15))
    except:
        return "nan"

# Dir-relevant (new Y?)
def new_X(x_coordinate, play_direction):
    return 120.0 - x_coordinate if play_direction == 'left' else x_coordinate

def new_line(rush_team, field_position, yardline):
    return 10.0 + yardline if rush_team == field_position else 60.0 + (50 - yardline)

def new_orientation(angle, play_direction):
    return angle if angle == 0.0 or play_direction == 'right' else 360.0 - angle

def euclidean_distance(x1,y1,x2,y2):
    return np.sqrt((x1-x2)**2 + (y1-y2)**2)

def back_direction(orientation):
    return 1 if orientation > 180.0 else 0

# %%
# deal with features
def preprocess(train):
    # GameClock
    # train['GameClock_sec'] = train['GameClock'].apply(lambda x : x.split(":")[0] * 60 + x.split(":")[1])
    # train["GameClock_sec"] = train["GameClock"].apply(lambda x : x.split(":")[0]).astype("object")

    # Height
    train['PlayerHeight'] = train['PlayerHeight'].apply(lambda x: 12*int(x.split('-')[0])+int(x.split('-')[1]))

    # Time
    train['TimeHandoff'] = train['TimeHandoff'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
    train['TimeSnap'] = train['TimeSnap'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
    train['TimeDelta'] = train.apply(lambda row: (row['TimeHandoff'] - row['TimeSnap']).total_seconds(), axis=1)

    # Age
    seconds_in_year = 60*60*24*365.25
    train['PlayerBirthDate'] = train['PlayerBirthDate'].apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y"))
    train['PlayerAge'] = train.apply(lambda row: (row['TimeHandoff']-row['PlayerBirthDate']).total_seconds()/seconds_in_year, axis=1)
    # train["PlayerAge_ob"] = train['PlayerAge'].astype(np.int).astype("object")

    # WindSpeed
    train['WindSpeed'] = train['WindSpeed'].apply(lambda x: x.lower().replace('mph', '').strip() if not pd.isna(x) else x)
    train['WindSpeed'] = train['WindSpeed'].apply(lambda x: (int(x.split('-')[0])+int(x.split('-')[1]))/2 if not pd.isna(x) and '-' in x else x)
    train['WindSpeed'] = train['WindSpeed'].apply(lambda x: (int(x.split()[0])+int(x.split()[-1]))/2 if not pd.isna(x) and type(x)!=float and 'gusts up to' in x else x)
    train['WindSpeed'] = train['WindSpeed'].apply(lambda x: 0.0 if x == 'calm' else x)
    #condition = train['WindSpeed'].apply(lambda x: True if x in ['ssw','se','e'] else False)
    #a,b = train['WindSpeed'][condition], train['WindDirection'][condition]
    #train['WindSpeed'][condition], train['WindDirection'][condition] = b, a
    train['WindSpeed'] = train['WindSpeed'].apply(strToFloat)

    # Weather
    # deal (T: 51; H: 55; W: NW 10 mph)
    train['GameWeather'] = train['GameWeather'].str.lower()
    train['GameWeather'] = train['GameWeather'].apply(lambda x: "indoor" if not pd.isna(x) and "indoor" in x else x)
    train['GameWeather'] = train['GameWeather'].apply(lambda x: x.replace('coudy', 'cloudy').replace('clouidy', 'cloudy').replace('party', 'partly') if not pd.isna(x) else x)
    train['GameWeather'] = train['GameWeather'].apply(lambda x: x.replace('clear and sunny', 'sunny and clear') if not pd.isna(x) else x)
    train['GameWeather'] = train['GameWeather'].apply(lambda x: x.replace('skies', '').replace("mostly", "").strip() if not pd.isna(x) else x)
    train['GameWeather_dense'] = train['GameWeather'].apply(mapWeather)

    # Rusher
    train['IsRusher'] = (train['NflId'] == train['NflIdRusher'])
    temp = train[train["IsRusher"]][["Team", "PlayId"]].rename(columns={"Team":"RusherTeam"})
    train = train.merge(temp, on = "PlayId")
    train["IsRusherTeam"] = (train["Team"] == train["RusherTeam"])
    
    # Orientation and Dir
    train["Orientation_ob"] = train["Orientation"].apply(lambda x : orientationToCat(x)).astype("object")
    train["Dir_ob"] = train["Dir"].apply(lambda x : orientationToCat(x)).astype("object")

    train["Orientation_sin"] = train["Orientation"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
    train["Orientation_cos"] = train["Orientation"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
    train["Dir_sin"] = train["Dir"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
    train["Dir_cos"] = train["Dir"].apply(lambda x : np.cos(x/360 * 2 * np.pi))

    # diff Score 
    train["diffScoreBeforePlay"] = train["HomeScoreBeforePlay"] - train["VisitorScoreBeforePlay"]
    # train["diffScoreBeforePlay"] = abs(train["HomeScoreBeforePlay"] - train["VisitorScoreBeforePlay"])
    # train["diffScoreBeforePlay"] = (train["HomeScoreBeforePlay"] - train["VisitorScoreBeforePlay"]) * (-1 or 1)
    train["diffScoreBeforePlay_binary_ob"] = (train["HomeScoreBeforePlay"] > train["VisitorScoreBeforePlay"]).astype("object")

    # Turf
    Turf = {'Field Turf':'Artificial', 'A-Turf Titan':'Artificial', 'Grass':'Natural', 'UBU Sports Speed S5-M':'Artificial',
            'Artificial':'Artificial', 'DD GrassMaster':'Artificial', 'Natural Grass':'Natural', 'UBU Speed Series-S5-M':'Artificial', 
            'FieldTurf':'Artificial', 'FieldTurf 360':'Artificial', 'Natural grass':'Natural', 'grass':'Natural', 
            'Natural':'Natural', 'Artifical':'Artificial', 'FieldTurf360':'Artificial', 'Naturall Grass':'Natural', 
            'Field turf':'Artificial', 'SISGrass':'Artificial', 'Twenty-Four/Seven Turf':'Artificial', 'natural grass':'Natural'} 
    train['Turf'] = train['Turf'].map(Turf)

    # OffensePersonnel
    temp = train['OffensePersonnel'][np.arange(0, len(train), 22)].apply(lambda x : pd.Series(offensePersonnelSplit(x)))
    temp.columns = ["Offense" + c for c in temp.columns]
    temp["PlayId"] = train['PlayId'][np.arange(0, len(train), 22)]
    train = train.merge(temp, on = "PlayId")

    # DefensePersonnel
    temp = train['DefensePersonnel'][np.arange(0, len(train), 22)].apply(lambda x : pd.Series(DefensePersonnelSplit(x)))
    temp.columns = ["Defense" + c for c in temp.columns]
    temp["PlayId"] = train['PlayId'][np.arange(0, len(train), 22)]
    train = train.merge(temp, on = "PlayId")

    # numerical -> categorical
    train["Quarter"] = train["Quarter"].astype("object")
    train["Down"] = train["Down"].astype("object")
    train["JerseyNumber"] = train["JerseyNumber"].astype("object")
    # train["YardLine"] = train["YardLine"].astype("object")
    # train["DefendersInTheBox"] = train["DefendersInTheBox"].astype("object")
    # train["Week"] = train["Week"].astype("object")

    # Dir-relevant
    train['YardLine'] = train[['PossessionTeam','FieldPosition','YardLine']].apply(lambda x: new_line(x[0],x[1],x[2]), axis=1)
    train['X'] = train[['X','PlayDirection']].apply(lambda x: new_X(x[0],x[1]), axis=1)
    train['Orientation'] = train[['Orientation','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)
    train['Dir'] = train[['Dir','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)
    
    # OffenseFormation
    off_list = ['I_FORM','SHOTGUN','SINGLEBACK']
    for offf in off_list:
        train['OffenseFormation_' + offf] = 0
        train.loc[train['OffenseFormation'] == offf,'OffenseFormation_'+offf] = 1

    
    # Encoder
#     le_dict = {}
#     categoricals = ["Team_le", "NflIdRusher_le", "DisplayName_le", "PlayerCollegeName_le", "Position_le",
#                     'OffenseFormation_le', 'OffensePersonnel_le', 'DefensePersonnel_le', 'PlayDirection_le',
#                     'HomeTeamAbbr_le', 'VisitorTeamAbbr_le', 'Stadium_le', 'Location_le', 'StadiumType_le', 'Turf_le', 'GameWeather_le', "WindDirection_le"]

#     for cat in categoricals:
#         le_dict[cat] = LabelEncoder()
#         train[cat] = le_dict[cat].fit_transform(train[cat[:-3]].apply(str))
    
    # sort
#     train = train.sort_values(by = ['X']).sort_values(by = ['Dis']).sort_values(by=['PlayId', 'Team', 'IsRusher']).reset_index(drop = True)
#     train = train.sort_values(by = ['X']).sort_values(by = ['Dis']).sort_values(by=['PlayId', 'IsRusherTeam', 'IsRusher']).reset_index(drop = True)
    return train

# %%
train_df = preprocess(train_df)
# train_df = train_df.drop(columns=[])

# %% [markdown]
# <a id="4"></a> <br>
# # Feature Selection

# %%
# create new features
def createFeatures(train, outcomes=None, deploy=False):
#     def defense_possession_features(df):
#         rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','X','Y']]
#         rusher.columns = ['GameId','PlayId','RusherX','RusherY']
#         defense = pd.merge(df,rusher,on=['GameId','PlayId'],how='inner')
#         defense = defense[defense['Team'] != defense['RusherTeam']][['GameId','PlayId','NflId','X','Y','RusherX','RusherY']]
#         defense['def_dist_to_back'] = defense[['X','Y','RusherX','RusherY']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)
#         defense_p = defense.groupby(['NflId']).agg({'NflId':['count']}).reset_index()
#         defense_p.columns = ['NflId','Possessions']
#         defense_p = pd.merge(defense[['GameId','PlayId','NflId','def_dist_to_back']],defense_p,on=['NflId'],how='inner')
#         #Might test 2/4/6 or even larger
#         defense_Ip = defense_p[defense_p['def_dist_to_back']<=6]
#         defense_Ip = defense_Ip.groupby(['NflId']).agg({'NflId':['count']}).reset_index()
#         defense_Ip.columns = ['NflId','In_place']
#         defense_Ip = pd.merge(defense_p,defense_Ip,on=['NflId'],how='inner')
#         defense_Ip['In_place_times_100'] = defense_Ip['In_place'] / defense_Ip['Possessions'] * 100
#         defense_Ip = defense_Ip.drop(columns = ['Possessions','In_place'])
#         def add_sf(group):
#             temp_dist = group['def_dist_to_back'][group['def_dist_to_back']<=30]
#             Stemp = np.exp(temp_dist)/sum(np.exp(temp_dist))
#             group['Sum_in_place_of_100'] = sum(Stemp * group['In_place_times_100'])
#             group.loc[group['Sum_in_place_of_100'].isna(),'Sum_in_place_of_100'] = 0
#             return group
#         defense_Ip = defense_Ip.groupby(['GameId','PlayId']).apply(add_sf)
#         defense_Ip = defense_Ip.drop(columns = ['NflId','def_dist_to_back','In_place_times_100'])
#         defense_Ip = defense_Ip.groupby(['GameId','PlayId']).mean().reset_index()
#         defense_Ip.columns = ['GameId','PlayId','Sum_in_place_of_100']
#         return defense_Ip     
    
    def defensor_speed_features(df):
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','X','Y']]
        rusher.columns = ['GameId','PlayId','RusherX','RusherY']

        defense = pd.merge(df,rusher,on=['GameId','PlayId'],how='inner')
        defense = defense[defense['Team'] != defense['RusherTeam']][['GameId','PlayId','X','Y','RusherX','RusherY','S']]
        defense['def_dist_to_back'] = defense[['X','Y','RusherX','RusherY']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        defense1 = defense.copy()
        def_S_index = defense.groupby(['GameId','PlayId'])['def_dist_to_back'].idxmin()
        defense = defense.groupby(['GameId','PlayId'])\
                             .agg({'def_dist_to_back':['min','max','mean','std']})\
                             .reset_index()
        defense.columns = ['GameId','PlayId','def_min_dist','def_max_dist','def_mean_dist','def_std_dist']
        defense['def_S'] = defense1.loc[def_S_index.values].reset_index().S
        defense['def_S'] = defense['def_S']+0.05
        defense['min_time_to_tackle_S'] = defense['def_min_dist']/(defense['def_S'])
        defense = defense.drop(columns = ['def_min_dist', 'def_max_dist', 'def_mean_dist', 'def_std_dist'])
        
        return defense
    
    # back features
    def back_features(df):
        # carriers
        carriers = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','NflIdRusher','X','Y','Orientation','Dir','YardLine']]
        carriers['back_from_scrimmage'] = carriers['YardLine'] - carriers['X']
        carriers['back_oriented_down_field'] = carriers['Orientation'].apply(lambda x: back_direction(x))
        carriers['back_moving_down_field'] = carriers['Dir'].apply(lambda x: back_direction(x))
        carriers = carriers.rename(columns={'X':'back_X',
                                            'Y':'back_Y'})
        carriers = carriers[['GameId','PlayId','NflIdRusher','back_X','back_Y','back_from_scrimmage','back_oriented_down_field','back_moving_down_field']]
        return carriers

    def features_relative_to_back(df, carriers):
        # both offense and defense
        player_distance = df[['GameId','PlayId','NflId','X','Y','Team','RusherTeam']]
        player_distance = pd.merge(player_distance, carriers, on=['GameId','PlayId'], how='inner')
        player_distance = player_distance[player_distance['NflId'] != player_distance['NflIdRusher']]
        player_distance['dist_to_back'] = player_distance[['X','Y','back_X','back_Y']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)
        player_distance['def_in_box_5'] = player_distance[['dist_to_back','Team','RusherTeam']].apply(lambda x: 1 if x[0]<=5.0 and (x[1]!=x[2]) else 0,axis=1)
        player_distance['off_in_box_5'] = player_distance[['dist_to_back','Team','RusherTeam']].apply(lambda x: 1 if x[0]<=5.0 and (x[1]==x[2]) else 0,axis=1)
        player_distance['def_in_box_10'] = player_distance[['dist_to_back','Team','RusherTeam']].apply(lambda x: 1 if x[0]<=10.0 and (x[1]!=x[2]) else 0,axis=1)
        player_distance['off_in_box_10'] = player_distance[['dist_to_back','Team','RusherTeam']].apply(lambda x: 1 if x[0]<=10.0 and (x[1]==x[2]) else 0,axis=1)
        player_distance = player_distance.groupby(['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field'])\
                                         .agg({'dist_to_back':['min','max','mean','std'], 'def_in_box_5':['sum'], 'off_in_box_5':['sum'],
                                              'def_in_box_10':['sum'], 'off_in_box_10':['sum']})\
                                         .reset_index()
        player_distance.columns = ['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field',
                                   'min_dist','max_dist','mean_dist','std_dist','def_in_box_5','off_in_box_5','def_in_box_10','off_in_box_10']
        player_distance['def_in_box_10'] = player_distance['def_in_box_10'] - player_distance['def_in_box_5']
        player_distance['off_in_box_10'] = player_distance['off_in_box_10'] - player_distance['off_in_box_5']

        return player_distance

    # defense
    def defense_features(df):
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','X','Y']]
        rusher.columns = ['GameId','PlayId','RusherX','RusherY']

        defense = pd.merge(df,rusher,on=['GameId','PlayId'],how='inner')
        defense = defense[defense['Team'] != defense['RusherTeam']][['GameId','PlayId','X','Y','RusherX','RusherY','S']]
        defense['def_dist_to_back'] = defense[['X','Y','RusherX','RusherY']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)
        defense['tackle_time'] = defense[['def_dist_to_back','S']].apply(lambda x: x[0]/(x[1]+0.05),axis=1)
        defense['new_X'] = defense[['X','RusherX']].apply(lambda x: x[0]-x[1],axis=1)
        
        defense = defense.groupby(['GameId','PlayId'])\
                         .agg({'def_dist_to_back':['min','max','mean','std'],'Y':['min','max','std'],'X':['min','max','std'],
                               'tackle_time':['min','max','mean','std'],'new_X':['std']})\
                         .reset_index()
        defense.columns = ['GameId','PlayId','def_min_dist','def_max_dist','def_mean_dist','def_std_dist',
                           'Y_min','Y_max','def_Y_std','X_min','X_max','def_X_std','def_tackle_time_min','def_tackle_time_max','def_tackle_time_mean',
                          'def_tackle_time_std','def_new_X_std']
#         defense = defense.groupby(['GameId','PlayId'])\
#                          .agg({'def_dist_to_back':['min','max','mean','std'],'Y':['min','max','std'],'X':['min','max','std'],
#                                'tackle_time':['min','max','mean','std'],'new_X':['std'], 'DefenseDL':['sum']})\
#                          .reset_index()
#         defense.columns = ['GameId','PlayId','def_min_dist','def_max_dist','def_mean_dist','def_std_dist',
#                            'Y_min','Y_max','def_Y_std','X_min','X_max','def_X_std','def_tackle_time_min','def_tackle_time_max','def_tackle_time_mean',
#                           'def_tackle_time_std','def_new_X_std','DefenseDL']
        defense['def_Y_spread'] = defense[['Y_min','Y_max']].apply(lambda x: x[1]-x[0], axis=1)
        defense['def_X_spread'] = defense[['X_min','X_max']].apply(lambda x: x[1]-x[0], axis=1)
        defense = defense.drop(columns=['Y_min','Y_max','X_min','X_max'])
        

        return defense
    
    # rusher 
    def rusher_features(df):
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Dir', 'S', 'A', 'X', 'Y']]
        rusher.columns = ['GameId','PlayId', 'RusherDir', 'RusherS', 'RusherA', 'RusherX', 'RusherY']
       
        radian_angle = (90 - rusher['RusherDir']) * np.pi / 180.0
        v_horizontal = np.abs(rusher['RusherS'] * np.cos(radian_angle))
        v_vertical = np.abs(rusher['RusherS'] * np.sin(radian_angle)) 
       
        rusher['v_horizontal'] = v_horizontal
        rusher['v_vertical'] = v_vertical
        
        rusher = rusher.drop(columns=['RusherDir','RusherS', 'RusherA','RusherX','RusherY'])
        return rusher
    
    # offense     
    def offense_features(df):
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','X','Y']]
        rusher.columns = ['GameId','PlayId','RusherX','RusherY']

        offense = pd.merge(df,rusher,on=['GameId','PlayId'],how='inner')
        offense = offense[offense['Team'] == offense['RusherTeam']][offense['NflId'] != offense['NflIdRusher']][['GameId','PlayId','X','Y','RusherX','RusherY','S']]
        offense['off_dist_to_back'] = offense[['X','Y','RusherX','RusherY']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)
        offense['tackle_time'] = offense[['off_dist_to_back','S']].apply(lambda x: x[0]/(x[1]+0.05),axis=1)
        offense['new_X'] = offense[['X','RusherX']].apply(lambda x: x[0]-x[1],axis=1)
        
        offense = offense.groupby(['GameId','PlayId'])\
                         .agg({'off_dist_to_back':['min','max','mean','std'],'Y':['min','max','std'],'X':['min','max','std'],
                               'tackle_time':['min','max','mean','std'],'new_X':['std']})\
                         .reset_index()
        offense.columns = ['GameId','PlayId','off_min_dist','off_max_dist','off_mean_dist','off_std_dist',
                           'Y_min','Y_max','off_Y_std', 'X_min','X_max','off_X_std','off_tackle_time_min','off_tackle_time_max','off_tackle_time_mean',
                          'off_tackle_time_std','off_new_X_std']
#         offense = offense.groupby(['GameId','PlayId'])\
#                          .agg({'off_dist_to_back':['min','max','mean','std'],'Y':['min','max','std'],'X':['min','max','std'],
#                                'tackle_time':['min','max','mean','std'],'new_X':['std'], 'OffenseOL':['sum'],'OffenseTE':['sum'],
#                                'OffenseWR':['sum']})\
#                          .reset_index()
#         offense.columns = ['GameId','PlayId','off_min_dist','off_max_dist','off_mean_dist','off_std_dist',
#                            'Y_min','Y_max','off_Y_std', 'X_min','X_max','off_X_std','off_tackle_time_min','off_tackle_time_max','off_tackle_time_mean',
#                           'off_tackle_time_std','off_new_X_std','OffenseOL','OffenseTE','OffenseWR']
        offense['off_Y_spread'] = offense[['Y_min','Y_max']].apply(lambda x: x[1]-x[0], axis=1)
        offense['off_X_spread'] = offense[['X_min','X_max']].apply(lambda x: x[1]-x[0], axis=1)
        
        offense = offense.drop(columns=['Y_min','Y_max','X_min','X_max'])

        return offense
    
    # other features
    def static_features(df):
        basic_feas = ['GameId','PlayId','X','Y','S','A','Dis','Orientation','Dir',
                      'YardLine','Quarter','Distance','DefendersInTheBox', 'OffenseFormation_I_FORM', 
                      'OffenseFormation_SHOTGUN','OffenseFormation_SINGLEBACK', 'Down']


        add_new_feas = ['PlayerHeight', 'PlayerAge', 'WindSpeed', 'GameWeather_dense','Dir_sin',
                        'Dir_cos', 'diffScoreBeforePlay'] # PlayerWeight
    
        static_features = df[df['NflId'] == df['NflIdRusher']][add_new_feas+basic_feas].drop_duplicates()
        static_features.fillna(-999,inplace=True) # fill NA value
        # static_features[i] = static_features[i].fillna(np.mean(static_features[i]))
        return static_features


    def combine_features(relative_to_back, defense, defensor, offense, rush, static, deploy=deploy):
        df = pd.merge(relative_to_back,defense,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df, defensor, on=['GameId','PlayId'],how='inner')
        #df = pd.merge(df,possession,on=['GameId','PlayId'],how='inner') 
        df = pd.merge(df,offense,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,rush,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,static,on=['GameId','PlayId'],how='inner')
        #df['off_on_def'] = df[['def_in_box','off_in_box']].apply(lambda x: float(x[1])/float(x[0]),axis=1)
        df['runner_vs_1stdefensor_speed'] = df['S']/df['def_S']
        return df
    
    back_feats = back_features(train)
    rel_back = features_relative_to_back(train, back_feats)
    def_feats = defense_features(train)
    off_feats = offense_features(train)
    # defense_possession_feats = defense_possession_features(train)
    defensor_speed_feats = defensor_speed_features(train)
    rush_feats = rusher_features(train)
    static_feats = static_features(train)
    train = combine_features(rel_back, def_feats, defensor_speed_feats, off_feats,rush_feats, static_feats, deploy=deploy)
    
    # train or test data
    if not deploy:
        train = pd.merge(train, outcomes, on=['GameId','PlayId'], how='inner')

    return train

# %%
train_df = createFeatures(train_df, outcomes)

# %% [markdown]
# <a id="5"></a> <br>
# # NN Model and CV

# %%
# construct X and y
X = train_df.copy()
yards = X.Yards
pca = PCA(n_components=50)
y = np.zeros((yards.shape[0], 199))
for idx, target in enumerate(list(yards)):
    y[idx][99 + target] = 1

X.drop(['GameId','PlayId','Yards'], axis=1, inplace=True)
scaler = StandardScaler()
X = scaler.fit_transform(X)
# pca.fit(X)
# X = pca.transform(X)
# print(pca.explained_variance_ratio_[:50].sum())
# train and test data
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15, random_state=12345)

# %%
# callback
class CRPSCallback(Callback):
    def __init__(self, validation, predict_batch_size=20, include_on_batch=False):
        super(CRPSCallback, self).__init__()
        self.validation = validation
        self.predict_batch_size = predict_batch_size
        self.include_on_batch = include_on_batch
        print('validation shape',len(self.validation))

    def on_batch_begin(self, batch, logs={}):
        pass

    def on_train_begin(self, logs={}):
        if not ('CRPS_score_val' in self.params['metrics']):
            self.params['metrics'].append('CRPS_score_val')

    def on_batch_end(self, batch, logs={}):
        if (self.include_on_batch):
            logs['CRPS_score_val'] = float('-inf')

    def on_epoch_end(self, epoch, logs={}):
        logs['CRPS_score_val'] = float('-inf')
            
        if (self.validation):
            X_valid, y_valid = self.validation[0], self.validation[1]
            y_pred = self.model.predict(X_valid)
            y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
            y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
            val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * X_valid.shape[0])
            val_s = np.round(val_s, 6)
            logs['CRPS_score_val'] = val_s

# NN Model
def get_model(x_tr,y_tr,x_val,y_val):
    # model
    inp = Input(shape = (x_tr.shape[1],))
    x = Dense(512, input_dim=X.shape[1], activation='relu')(inp)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    out = Dense(199, activation='softmax')(x)
    model = Model(inp,out)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=[])
    # add lookahead ?PyTorch
    # lookahead = Lookahead(k=5, alpha=0.5) # Initialize Lookahead
    # lookahead.inject(model) # add into model
    
    es = EarlyStopping(monitor='CRPS_score_val', 
                       mode='min',
                       restore_best_weights=True, 
                       verbose=1, 
                       patience=10)

    mc = ModelCheckpoint('best_model.h5',monitor='CRPS_score_val',mode='min',
                         save_best_only=True, verbose=1, save_weights_only=True)
    
    bsz = 1024
    steps = x_tr.shape[0]/bsz
    
    model.fit(x_tr, y_tr,callbacks=[CRPSCallback(validation = (x_val,y_val)),es,mc], epochs=100, batch_size=bsz,verbose=1)
    model.load_weights("best_model.h5")
    y_pred = model.predict(x_val)
    y_valid = y_val
    y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * x_val.shape[0])
    crps = np.round(val_s, 6)

    return model,crps

# %%
# # NN Model
# def CRPS(y_true,y_pred):
# #     val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * x_val.shape[0])
# #     crps = np.round(val_s, 6)
#     sum1 = tf.keras.backend.sum(
#         ((y_true - y_pred) ** 2),
#         axis=1, keepdims=True)
#     return tf.keras.backend.sum(sum1,axis=0, keepdims=True)/ tf.dtypes.cast((199 * tf.shape(y_true)[0]), tf.float32)
   
# def build_model(hp):
# #     # model
#     # dense1 = hp.Int('units',min_value=256,max_value=1024,step=32,default=1024)
#     # dropout1 = hp.Choice('dropout', [0.5, 0.2, 0.8])
#     dense2 = hp.Int('units',min_value=256,max_value=1024,step=32,default=512)
#     dropout2 = hp.Choice('dropout', [0.5, 0.2, 0.8])
#     dense3 = 256 # hp.Int('units',min_value=128,max_value=512,step=32,default=256)
#     dropout3 = 0.5 # hp.Choice('dropout', [0.5, 0.2, 0.8])
    
#     inp = Input(shape = (X_train.shape[1],))
#     #x = GaussianNoise(stddev=0.25)(inp)
#     x = Dense(units=512, activation='relu')(inp)
#     x = Dropout(0.5)(x)
#     x = BatchNormalization()(x)
#     #x = GaussianNoise(stddev=0.1)(x)
    
#     x = Dense(units=dense2, activation='relu')(x)
#     x = Dropout(dropout2)(x)
#     x = BatchNormalization()(x)
#     #x = GaussianNoise(stddev=0.1)(x)
        
#     x = Dense(units=dense3, activation='relu')(x)
#     x = Dropout(dropout3)(x)
#     x = BatchNormalization()(x)
    
#     out = Dense(199, activation='softmax')(x)
#     model = Model(inp,out)
#     model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=[CRPS])
#     return model
# tuner = RandomSearch(
#     build_model,
#     objective=kt.Objective('val_CRPS', 'min'),
#     max_trials=5,
#     executions_per_trial=2,
#     directory='.')

# #tuner.search_space_summary()

# tuner.search(x=X,
#              y=y,
#              epochs=100, validation_split=0.2)

# %%
#tuner.results_summary()

# %%
# from tensorflow.keras.utils import plot_model
# model = tuner.get_best_models(num_models=1)
# plot_model(model[0], to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# Cross Validation
losses, models, crps_csv = [], [], []
s_time = time.time()

for k in range(2):
    kfold = KFold(5, random_state = 42 + k, shuffle = True) # different random state
    for k_fold, (tr_inds, val_inds) in enumerate(kfold.split(yards)):
        print("-----------")
        print("-----------")
        tr_x,tr_y = X[tr_inds],y[tr_inds]
        val_x,val_y = X[val_inds],y[val_inds]
        model,crps = get_model(tr_x,tr_y,val_x,val_y)
        models.append(model)
        print("the %d fold crps is %f"%((k_fold+1),crps))
        crps_csv.append(crps)
# Out:
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 5.6317
# Epoch 00001: CRPS_score_val improved from inf to 0.08334, saving model to best_model.h5
# 18536/18536 [==============================] - 2s 131us/sample - loss: 5.6309 - CRPS_score_val: 0.0833
# Epoch 2/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 5.2439
# Epoch 00002: CRPS_score_val improved from 0.08334 to 0.07816, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 62us/sample - loss: 5.2332 - CRPS_score_val: 0.0782
# Epoch 3/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 4.8460
# Epoch 00003: CRPS_score_val improved from 0.07816 to 0.06920, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 63us/sample - loss: 4.8356 - CRPS_score_val: 0.0692
# Epoch 4/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 4.4379
# Epoch 00004: CRPS_score_val improved from 0.06920 to 0.05082, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 62us/sample - loss: 4.4258 - CRPS_score_val: 0.0508
# Epoch 5/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 3.9784
# Epoch 00005: CRPS_score_val improved from 0.05082 to 0.03209, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 3.9778 - CRPS_score_val: 0.0321
# Epoch 6/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 3.6121
# Epoch 00006: CRPS_score_val improved from 0.03209 to 0.02073, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 60us/sample - loss: 3.6117 - CRPS_score_val: 0.0207
# Epoch 7/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 3.3100
# Epoch 00007: CRPS_score_val improved from 0.02073 to 0.01600, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 3.3101 - CRPS_score_val: 0.0160
# Epoch 8/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 3.1225
# Epoch 00008: CRPS_score_val improved from 0.01600 to 0.01422, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 60us/sample - loss: 3.1237 - CRPS_score_val: 0.0142
# Epoch 9/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 3.0116
# Epoch 00009: CRPS_score_val improved from 0.01422 to 0.01363, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 3.0108 - CRPS_score_val: 0.0136
# Epoch 10/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.9603
# Epoch 00010: CRPS_score_val improved from 0.01363 to 0.01340, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.9560 - CRPS_score_val: 0.0134
# Epoch 11/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.9012
# Epoch 00011: CRPS_score_val improved from 0.01340 to 0.01328, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.8998 - CRPS_score_val: 0.0133
# Epoch 12/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.8704
# Epoch 00012: CRPS_score_val improved from 0.01328 to 0.01322, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.8717 - CRPS_score_val: 0.0132
# Epoch 13/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.8638
# Epoch 00013: CRPS_score_val improved from 0.01322 to 0.01319, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.8577 - CRPS_score_val: 0.0132
# Epoch 14/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.8270
# Epoch 00014: CRPS_score_val improved from 0.01319 to 0.01315, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.8291 - CRPS_score_val: 0.0132
# Epoch 15/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.8159
# Epoch 00015: CRPS_score_val improved from 0.01315 to 0.01313, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 62us/sample - loss: 2.8158 - CRPS_score_val: 0.0131
# Epoch 16/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.8051
# Epoch 00016: CRPS_score_val improved from 0.01313 to 0.01309, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 62us/sample - loss: 2.8062 - CRPS_score_val: 0.0131
# Epoch 17/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.7934
# Epoch 00017: CRPS_score_val improved from 0.01309 to 0.01307, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 67us/sample - loss: 2.7931 - CRPS_score_val: 0.0131
# Epoch 18/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.7862
# Epoch 00018: CRPS_score_val improved from 0.01307 to 0.01305, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 63us/sample - loss: 2.7860 - CRPS_score_val: 0.0131
# Epoch 19/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.7678
# Epoch 00019: CRPS_score_val improved from 0.01305 to 0.01304, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.7681 - CRPS_score_val: 0.0130
# Epoch 20/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.7627
# Epoch 00020: CRPS_score_val improved from 0.01304 to 0.01303, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.7658 - CRPS_score_val: 0.0130
# Epoch 21/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.7603
# Epoch 00021: CRPS_score_val did not improve from 0.01303
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.7597 - CRPS_score_val: 0.0130
# Epoch 22/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.7530
# Epoch 00022: CRPS_score_val improved from 0.01303 to 0.01302, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.7534 - CRPS_score_val: 0.0130
# Epoch 23/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.7506
# Epoch 00023: CRPS_score_val improved from 0.01302 to 0.01300, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.7504 - CRPS_score_val: 0.0130
# Epoch 24/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.7416
# Epoch 00024: CRPS_score_val improved from 0.01300 to 0.01298, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.7442 - CRPS_score_val: 0.0130
# Epoch 25/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.7434
# Epoch 00025: CRPS_score_val improved from 0.01298 to 0.01298, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.7435 - CRPS_score_val: 0.0130
# Epoch 26/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.7408
# Epoch 00026: CRPS_score_val improved from 0.01298 to 0.01297, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 62us/sample - loss: 2.7410 - CRPS_score_val: 0.0130
# Epoch 27/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.7248
# Epoch 00027: CRPS_score_val improved from 0.01297 to 0.01297, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 62us/sample - loss: 2.7313 - CRPS_score_val: 0.0130
# Epoch 28/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.7235
# Epoch 00028: CRPS_score_val improved from 0.01297 to 0.01296, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.7234 - CRPS_score_val: 0.0130
# Epoch 29/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.7268
# Epoch 00029: CRPS_score_val did not improve from 0.01296
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.7266 - CRPS_score_val: 0.0130
# Epoch 30/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.7169
# Epoch 00030: CRPS_score_val improved from 0.01296 to 0.01295, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 63us/sample - loss: 2.7172 - CRPS_score_val: 0.0130
# Epoch 31/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.7153
# Epoch 00031: CRPS_score_val improved from 0.01295 to 0.01294, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.7157 - CRPS_score_val: 0.0129
# Epoch 32/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.7158
# Epoch 00032: CRPS_score_val improved from 0.01294 to 0.01293, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.7155 - CRPS_score_val: 0.0129
# Epoch 33/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.7139
# Epoch 00033: CRPS_score_val improved from 0.01293 to 0.01293, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.7137 - CRPS_score_val: 0.0129
# Epoch 34/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.7090
# Epoch 00034: CRPS_score_val improved from 0.01293 to 0.01292, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.7091 - CRPS_score_val: 0.0129
# Epoch 35/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.7067
# Epoch 00035: CRPS_score_val improved from 0.01292 to 0.01291, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.7071 - CRPS_score_val: 0.0129
# Epoch 36/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.7029
# Epoch 00036: CRPS_score_val did not improve from 0.01291
# 18536/18536 [==============================] - 1s 58us/sample - loss: 2.7039 - CRPS_score_val: 0.0129
# Epoch 37/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.7033
# Epoch 00037: CRPS_score_val improved from 0.01291 to 0.01290, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.7025 - CRPS_score_val: 0.0129
# Epoch 38/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.7011
# Epoch 00038: CRPS_score_val improved from 0.01290 to 0.01290, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.7043 - CRPS_score_val: 0.0129
# Epoch 39/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6955
# Epoch 00039: CRPS_score_val improved from 0.01290 to 0.01288, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.6951 - CRPS_score_val: 0.0129
# Epoch 40/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.7022
# Epoch 00040: CRPS_score_val did not improve from 0.01288
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.6999 - CRPS_score_val: 0.0129
# Epoch 41/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6964
# Epoch 00041: CRPS_score_val did not improve from 0.01288
# 18536/18536 [==============================] - 1s 59us/sample - loss: 2.6955 - CRPS_score_val: 0.0129
# Epoch 42/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.6915
# Epoch 00042: CRPS_score_val improved from 0.01288 to 0.01288, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.6915 - CRPS_score_val: 0.0129
# Epoch 43/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6810
# Epoch 00043: CRPS_score_val improved from 0.01288 to 0.01287, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.6850 - CRPS_score_val: 0.0129
# Epoch 44/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6834
# Epoch 00044: CRPS_score_val improved from 0.01287 to 0.01286, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.6842 - CRPS_score_val: 0.0129
# Epoch 45/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6914
# Epoch 00045: CRPS_score_val did not improve from 0.01286
# 18536/18536 [==============================] - 1s 58us/sample - loss: 2.6861 - CRPS_score_val: 0.0129
# Epoch 46/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6798
# Epoch 00046: CRPS_score_val did not improve from 0.01286
# 18536/18536 [==============================] - 1s 59us/sample - loss: 2.6800 - CRPS_score_val: 0.0129
# Epoch 47/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6835
# Epoch 00047: CRPS_score_val did not improve from 0.01286
# 18536/18536 [==============================] - 1s 59us/sample - loss: 2.6832 - CRPS_score_val: 0.0129
# Epoch 48/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.6827
# Epoch 00048: CRPS_score_val did not improve from 0.01286
# 18536/18536 [==============================] - 1s 58us/sample - loss: 2.6835 - CRPS_score_val: 0.0129
# Epoch 49/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6796
# Epoch 00049: CRPS_score_val did not improve from 0.01286
# 18536/18536 [==============================] - 1s 58us/sample - loss: 2.6796 - CRPS_score_val: 0.0129
# Epoch 50/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6712
# Epoch 00050: CRPS_score_val did not improve from 0.01286
# 18536/18536 [==============================] - 1s 58us/sample - loss: 2.6739 - CRPS_score_val: 0.0129
# Epoch 51/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.6683
# Epoch 00051: CRPS_score_val improved from 0.01286 to 0.01285, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.6680 - CRPS_score_val: 0.0129
# Epoch 52/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.6689
# Epoch 00052: CRPS_score_val improved from 0.01285 to 0.01285, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.6699 - CRPS_score_val: 0.0128
# Epoch 53/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6706
# Epoch 00053: CRPS_score_val did not improve from 0.01285
# 18536/18536 [==============================] - 1s 58us/sample - loss: 2.6702 - CRPS_score_val: 0.0129
# Epoch 54/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6753
# Epoch 00054: CRPS_score_val did not improve from 0.01285
# 18536/18536 [==============================] - 1s 59us/sample - loss: 2.6704 - CRPS_score_val: 0.0128
# Epoch 55/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6718
# Epoch 00055: CRPS_score_val did not improve from 0.01285
# 18536/18536 [==============================] - 1s 58us/sample - loss: 2.6710 - CRPS_score_val: 0.0128
# Epoch 56/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.6663
# Epoch 00056: CRPS_score_val improved from 0.01285 to 0.01284, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.6665 - CRPS_score_val: 0.0128
# Epoch 57/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.6626
# Epoch 00057: CRPS_score_val improved from 0.01284 to 0.01283, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.6629 - CRPS_score_val: 0.0128
# Epoch 58/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.6598
# Epoch 00058: CRPS_score_val improved from 0.01283 to 0.01283, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.6591 - CRPS_score_val: 0.0128
# Epoch 59/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6623
# Epoch 00059: CRPS_score_val did not improve from 0.01283
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.6635 - CRPS_score_val: 0.0128
# Epoch 60/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6617
# Epoch 00060: CRPS_score_val improved from 0.01283 to 0.01283, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.6619 - CRPS_score_val: 0.0128
# Epoch 61/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6591
# Epoch 00061: CRPS_score_val improved from 0.01283 to 0.01282, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.6594 - CRPS_score_val: 0.0128
# Epoch 62/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6484
# Epoch 00062: CRPS_score_val improved from 0.01282 to 0.01281, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.6510 - CRPS_score_val: 0.0128
# Epoch 63/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.6525
# Epoch 00063: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.6526 - CRPS_score_val: 0.0128
# Epoch 64/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6490
# Epoch 00064: CRPS_score_val did not improve from 0.01280
# 18536/18536 [==============================] - 1s 58us/sample - loss: 2.6537 - CRPS_score_val: 0.0128
# Epoch 65/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6534
# Epoch 00065: CRPS_score_val did not improve from 0.01280
# 18536/18536 [==============================] - 1s 58us/sample - loss: 2.6530 - CRPS_score_val: 0.0128
# Epoch 66/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6561
# Epoch 00066: CRPS_score_val improved from 0.01280 to 0.01279, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.6531 - CRPS_score_val: 0.0128
# Epoch 67/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.6482
# Epoch 00067: CRPS_score_val did not improve from 0.01279
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.6490 - CRPS_score_val: 0.0128
# Epoch 68/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6436
# Epoch 00068: CRPS_score_val did not improve from 0.01279
# 18536/18536 [==============================] - 1s 59us/sample - loss: 2.6461 - CRPS_score_val: 0.0128
# Epoch 69/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.6423
# Epoch 00069: CRPS_score_val did not improve from 0.01279
# 18536/18536 [==============================] - 1s 59us/sample - loss: 2.6434 - CRPS_score_val: 0.0128
# Epoch 70/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.6426
# Epoch 00070: CRPS_score_val did not improve from 0.01279
# 18536/18536 [==============================] - 1s 64us/sample - loss: 2.6426 - CRPS_score_val: 0.0128
# Epoch 71/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6438
# Epoch 00071: CRPS_score_val did not improve from 0.01279
# 18536/18536 [==============================] - 1s 63us/sample - loss: 2.6455 - CRPS_score_val: 0.0128
# Epoch 72/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6404
# Epoch 00072: CRPS_score_val did not improve from 0.01279
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.6365 - CRPS_score_val: 0.0128
# Epoch 73/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6372
# Epoch 00073: CRPS_score_val did not improve from 0.01279
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.6363 - CRPS_score_val: 0.0128
# Epoch 74/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6359
# Epoch 00074: CRPS_score_val did not improve from 0.01279
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.6347 - CRPS_score_val: 0.0128
# Epoch 75/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.6329
# Epoch 00075: CRPS_score_val improved from 0.01279 to 0.01278, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.6322 - CRPS_score_val: 0.0128
# Epoch 76/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.6307
# Epoch 00076: CRPS_score_val did not improve from 0.01278
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.6300 - CRPS_score_val: 0.0128
# Epoch 77/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.6347
# Epoch 00077: CRPS_score_val improved from 0.01278 to 0.01278, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.6355 - CRPS_score_val: 0.0128
# Epoch 78/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6238
# Epoch 00078: CRPS_score_val improved from 0.01278 to 0.01278, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 61us/sample - loss: 2.6264 - CRPS_score_val: 0.0128
# Epoch 79/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6227
# Epoch 00079: CRPS_score_val did not improve from 0.01278
# 18536/18536 [==============================] - 1s 59us/sample - loss: 2.6248 - CRPS_score_val: 0.0128
# Epoch 80/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6276
# Epoch 00080: CRPS_score_val did not improve from 0.01278
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.6279 - CRPS_score_val: 0.0128
# Epoch 81/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6251
# Epoch 00081: CRPS_score_val did not improve from 0.01278
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.6273 - CRPS_score_val: 0.0128
# Epoch 82/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.6170
# Epoch 00082: CRPS_score_val improved from 0.01278 to 0.01276, saving model to best_model.h5
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.6171 - CRPS_score_val: 0.0128
# Epoch 83/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6195
# Epoch 00083: CRPS_score_val did not improve from 0.01276
# 18536/18536 [==============================] - 1s 59us/sample - loss: 2.6212 - CRPS_score_val: 0.0128
# Epoch 84/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.6209
# Epoch 00084: CRPS_score_val did not improve from 0.01276
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.6216 - CRPS_score_val: 0.0128
# Epoch 85/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6153
# Epoch 00085: CRPS_score_val did not improve from 0.01276
# 18536/18536 [==============================] - 1s 59us/sample - loss: 2.6144 - CRPS_score_val: 0.0128
# Epoch 86/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6178
# Epoch 00086: CRPS_score_val did not improve from 0.01276
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.6178 - CRPS_score_val: 0.0128
# Epoch 87/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6118
# Epoch 00087: CRPS_score_val did not improve from 0.01276
# 18536/18536 [==============================] - 1s 60us/sample - loss: 2.6147 - CRPS_score_val: 0.0128
# Epoch 88/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.6102
# Epoch 00088: CRPS_score_val did not improve from 0.01276
# 18536/18536 [==============================] - 1s 59us/sample - loss: 2.6092 - CRPS_score_val: 0.0128
# Epoch 89/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6045
# Epoch 00089: CRPS_score_val did not improve from 0.01276
# 18536/18536 [==============================] - 1s 59us/sample - loss: 2.6105 - CRPS_score_val: 0.0128
# Epoch 90/100
# 17408/18536 [===========================>..] - ETA: 0s - loss: 2.6132
# Epoch 00090: CRPS_score_val did not improve from 0.01276
# 18536/18536 [==============================] - 1s 63us/sample - loss: 2.6115 - CRPS_score_val: 0.0128
# Epoch 91/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.6138
# Epoch 00091: CRPS_score_val did not improve from 0.01276
# 18536/18536 [==============================] - 1s 73us/sample - loss: 2.6145 - CRPS_score_val: 0.0128
# Epoch 92/100
# 18432/18536 [============================>.] - ETA: 0s - loss: 2.6073Restoring model weights from the end of the best epoch.
#
# Epoch 00092: CRPS_score_val did not improve from 0.01276
# 18536/18536 [==============================] - 1s 79us/sample - loss: 2.6070 - CRPS_score_val: 0.0128
# Epoch 00092: early stopping
# the 1 fold crps is 0.012760
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 5.6407
# Epoch 00001: CRPS_score_val improved from inf to 0.08244, saving model to best_model.h5
# 18537/18537 [==============================] - 2s 129us/sample - loss: 5.6400 - CRPS_score_val: 0.0824
# Epoch 2/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 5.2594
# Epoch 00002: CRPS_score_val improved from 0.08244 to 0.07868, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 61us/sample - loss: 5.2498 - CRPS_score_val: 0.0787
# Epoch 3/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 4.8714
# Epoch 00003: CRPS_score_val improved from 0.07868 to 0.07075, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 62us/sample - loss: 4.8695 - CRPS_score_val: 0.0708
# Epoch 4/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 4.4683
# Epoch 00004: CRPS_score_val improved from 0.07075 to 0.05369, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 61us/sample - loss: 4.4577 - CRPS_score_val: 0.0537
# Epoch 5/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 4.0192
# Epoch 00005: CRPS_score_val improved from 0.05369 to 0.03511, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 63us/sample - loss: 4.0198 - CRPS_score_val: 0.0351
# Epoch 6/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 3.6220
# Epoch 00006: CRPS_score_val improved from 0.03511 to 0.02156, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 61us/sample - loss: 3.6227 - CRPS_score_val: 0.0216
# Epoch 7/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 3.3246
# Epoch 00007: CRPS_score_val improved from 0.02156 to 0.01628, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 61us/sample - loss: 3.3181 - CRPS_score_val: 0.0163
# Epoch 8/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 3.1149
# Epoch 00008: CRPS_score_val improved from 0.01628 to 0.01427, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 61us/sample - loss: 3.1112 - CRPS_score_val: 0.0143
# Epoch 9/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 3.0111
# Epoch 00009: CRPS_score_val improved from 0.01427 to 0.01352, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 61us/sample - loss: 3.0101 - CRPS_score_val: 0.0135
# Epoch 10/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.9447
# Epoch 00010: CRPS_score_val improved from 0.01352 to 0.01328, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 59us/sample - loss: 2.9435 - CRPS_score_val: 0.0133
# Epoch 11/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.8888
# Epoch 00011: CRPS_score_val improved from 0.01328 to 0.01317, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 61us/sample - loss: 2.8909 - CRPS_score_val: 0.0132
# Epoch 12/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.8699
# Epoch 00012: CRPS_score_val improved from 0.01317 to 0.01311, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 62us/sample - loss: 2.8716 - CRPS_score_val: 0.0131
# Epoch 13/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.8440
# Epoch 00013: CRPS_score_val improved from 0.01311 to 0.01306, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 62us/sample - loss: 2.8441 - CRPS_score_val: 0.0131
# Epoch 14/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.8184
# Epoch 00014: CRPS_score_val improved from 0.01306 to 0.01302, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 61us/sample - loss: 2.8193 - CRPS_score_val: 0.0130
# Epoch 15/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.8091
# Epoch 00015: CRPS_score_val improved from 0.01302 to 0.01300, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 63us/sample - loss: 2.8089 - CRPS_score_val: 0.0130
# Epoch 16/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.7913
# Epoch 00016: CRPS_score_val improved from 0.01300 to 0.01299, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 61us/sample - loss: 2.7941 - CRPS_score_val: 0.0130
# Epoch 17/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.7889
# Epoch 00017: CRPS_score_val improved from 0.01299 to 0.01298, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 62us/sample - loss: 2.7885 - CRPS_score_val: 0.0130
# Epoch 18/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.7769
# Epoch 00018: CRPS_score_val improved from 0.01298 to 0.01295, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 60us/sample - loss: 2.7776 - CRPS_score_val: 0.0130
# Epoch 19/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.7697
# Epoch 00019: CRPS_score_val improved from 0.01295 to 0.01293, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 60us/sample - loss: 2.7680 - CRPS_score_val: 0.0129
# Epoch 20/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.7633
# Epoch 00020: CRPS_score_val improved from 0.01293 to 0.01293, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 63us/sample - loss: 2.7639 - CRPS_score_val: 0.0129
# Epoch 21/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.7554
# Epoch 00021: CRPS_score_val improved from 0.01293 to 0.01291, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 62us/sample - loss: 2.7580 - CRPS_score_val: 0.0129
# Epoch 22/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.7514
# Epoch 00022: CRPS_score_val improved from 0.01291 to 0.01290, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 62us/sample - loss: 2.7518 - CRPS_score_val: 0.0129
# Epoch 23/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.7455
# Epoch 00023: CRPS_score_val improved from 0.01290 to 0.01289, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 63us/sample - loss: 2.7426 - CRPS_score_val: 0.0129
# Epoch 24/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.7414
# Epoch 00024: CRPS_score_val improved from 0.01289 to 0.01288, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 63us/sample - loss: 2.7413 - CRPS_score_val: 0.0129
# Epoch 25/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.7350
# Epoch 00025: CRPS_score_val improved from 0.01288 to 0.01287, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 62us/sample - loss: 2.7342 - CRPS_score_val: 0.0129
# Epoch 26/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.7375
# Epoch 00026: CRPS_score_val did not improve from 0.01287
# 18537/18537 [==============================] - 1s 59us/sample - loss: 2.7357 - CRPS_score_val: 0.0129
# Epoch 27/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.7289
# Epoch 00027: CRPS_score_val improved from 0.01287 to 0.01286, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 63us/sample - loss: 2.7280 - CRPS_score_val: 0.0129
# Epoch 28/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.7276
# Epoch 00028: CRPS_score_val improved from 0.01286 to 0.01285, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 62us/sample - loss: 2.7282 - CRPS_score_val: 0.0129
# Epoch 29/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.7138
# Epoch 00029: CRPS_score_val improved from 0.01285 to 0.01285, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 63us/sample - loss: 2.7174 - CRPS_score_val: 0.0128
# Epoch 30/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.7173
# Epoch 00030: CRPS_score_val improved from 0.01285 to 0.01283, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 60us/sample - loss: 2.7169 - CRPS_score_val: 0.0128
# Epoch 31/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.7143
# Epoch 00031: CRPS_score_val did not improve from 0.01283
# 18537/18537 [==============================] - 1s 59us/sample - loss: 2.7138 - CRPS_score_val: 0.0128
# Epoch 32/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.7162
# Epoch 00032: CRPS_score_val did not improve from 0.01283
# 18537/18537 [==============================] - 1s 60us/sample - loss: 2.7152 - CRPS_score_val: 0.0128
# Epoch 33/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.7094
# Epoch 00033: CRPS_score_val improved from 0.01283 to 0.01283, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 61us/sample - loss: 2.7090 - CRPS_score_val: 0.0128
# Epoch 34/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.7064
# Epoch 00034: CRPS_score_val improved from 0.01283 to 0.01280, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 61us/sample - loss: 2.7050 - CRPS_score_val: 0.0128
# Epoch 35/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.7084
# Epoch 00035: CRPS_score_val did not improve from 0.01280
# 18537/18537 [==============================] - 1s 60us/sample - loss: 2.7076 - CRPS_score_val: 0.0128
# Epoch 36/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.7049
# Epoch 00036: CRPS_score_val did not improve from 0.01280
# 18537/18537 [==============================] - 1s 60us/sample - loss: 2.7027 - CRPS_score_val: 0.0128
# Epoch 37/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.7001
# Epoch 00037: CRPS_score_val did not improve from 0.01280
# 18537/18537 [==============================] - 1s 59us/sample - loss: 2.6986 - CRPS_score_val: 0.0128
# Epoch 38/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6909
# Epoch 00038: CRPS_score_val improved from 0.01280 to 0.01279, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 62us/sample - loss: 2.6924 - CRPS_score_val: 0.0128
# Epoch 39/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6881
# Epoch 00039: CRPS_score_val improved from 0.01279 to 0.01278, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 61us/sample - loss: 2.6899 - CRPS_score_val: 0.0128
# Epoch 40/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6933
# Epoch 00040: CRPS_score_val did not improve from 0.01278
# 18537/18537 [==============================] - 1s 59us/sample - loss: 2.6956 - CRPS_score_val: 0.0128
# Epoch 41/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6861
# Epoch 00041: CRPS_score_val improved from 0.01278 to 0.01278, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 61us/sample - loss: 2.6862 - CRPS_score_val: 0.0128
# Epoch 42/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6943
# Epoch 00042: CRPS_score_val did not improve from 0.01278
# 18537/18537 [==============================] - 1s 60us/sample - loss: 2.6934 - CRPS_score_val: 0.0128
# Epoch 43/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6896
# Epoch 00043: CRPS_score_val improved from 0.01278 to 0.01277, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 61us/sample - loss: 2.6896 - CRPS_score_val: 0.0128
# Epoch 44/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6854
# Epoch 00044: CRPS_score_val did not improve from 0.01277
# 18537/18537 [==============================] - 1s 61us/sample - loss: 2.6856 - CRPS_score_val: 0.0128
# Epoch 45/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6834
# Epoch 00045: CRPS_score_val improved from 0.01277 to 0.01277, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 61us/sample - loss: 2.6831 - CRPS_score_val: 0.0128
# Epoch 46/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6867
# Epoch 00046: CRPS_score_val improved from 0.01277 to 0.01275, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 60us/sample - loss: 2.6847 - CRPS_score_val: 0.0128
# Epoch 47/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6791
# Epoch 00047: CRPS_score_val did not improve from 0.01275
# 18537/18537 [==============================] - 1s 60us/sample - loss: 2.6781 - CRPS_score_val: 0.0128
# Epoch 48/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6743
# Epoch 00048: CRPS_score_val did not improve from 0.01275
# 18537/18537 [==============================] - 1s 61us/sample - loss: 2.6769 - CRPS_score_val: 0.0128
# Epoch 49/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6779
# Epoch 00049: CRPS_score_val improved from 0.01275 to 0.01275, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 61us/sample - loss: 2.6760 - CRPS_score_val: 0.0127
# Epoch 50/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6740
# Epoch 00050: CRPS_score_val did not improve from 0.01275
# 18537/18537 [==============================] - 1s 60us/sample - loss: 2.6739 - CRPS_score_val: 0.0128
# Epoch 51/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6718
# Epoch 00051: CRPS_score_val improved from 0.01275 to 0.01274, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 61us/sample - loss: 2.6716 - CRPS_score_val: 0.0127
# Epoch 52/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6664
# Epoch 00052: CRPS_score_val did not improve from 0.01274
# 18537/18537 [==============================] - 1s 61us/sample - loss: 2.6638 - CRPS_score_val: 0.0127
# Epoch 53/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6712
# Epoch 00053: CRPS_score_val improved from 0.01274 to 0.01274, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 62us/sample - loss: 2.6729 - CRPS_score_val: 0.0127
# Epoch 54/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6693
# Epoch 00054: CRPS_score_val improved from 0.01274 to 0.01273, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 62us/sample - loss: 2.6693 - CRPS_score_val: 0.0127
# Epoch 55/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6622
# Epoch 00055: CRPS_score_val did not improve from 0.01273
# 18537/18537 [==============================] - 1s 59us/sample - loss: 2.6661 - CRPS_score_val: 0.0127
# Epoch 56/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6653
# Epoch 00056: CRPS_score_val improved from 0.01273 to 0.01273, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 61us/sample - loss: 2.6645 - CRPS_score_val: 0.0127
# Epoch 57/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6622
# Epoch 00057: CRPS_score_val did not improve from 0.01273
# 18537/18537 [==============================] - 1s 60us/sample - loss: 2.6621 - CRPS_score_val: 0.0127
# Epoch 58/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6554
# Epoch 00058: CRPS_score_val did not improve from 0.01273
# 18537/18537 [==============================] - 1s 60us/sample - loss: 2.6579 - CRPS_score_val: 0.0127
# Epoch 59/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6597
# Epoch 00059: CRPS_score_val improved from 0.01273 to 0.01272, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 60us/sample - loss: 2.6594 - CRPS_score_val: 0.0127
# Epoch 60/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6593
# Epoch 00060: CRPS_score_val did not improve from 0.01272
# 18537/18537 [==============================] - 1s 59us/sample - loss: 2.6588 - CRPS_score_val: 0.0127
# Epoch 61/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6571
# Epoch 00061: CRPS_score_val improved from 0.01272 to 0.01271, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 61us/sample - loss: 2.6562 - CRPS_score_val: 0.0127
# Epoch 62/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6559
# Epoch 00062: CRPS_score_val did not improve from 0.01271
# 18537/18537 [==============================] - 1s 59us/sample - loss: 2.6533 - CRPS_score_val: 0.0127
# Epoch 63/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6538
# Epoch 00063: CRPS_score_val improved from 0.01271 to 0.01271, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 61us/sample - loss: 2.6543 - CRPS_score_val: 0.0127
# Epoch 64/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6531
# Epoch 00064: CRPS_score_val improved from 0.01271 to 0.01271, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 68us/sample - loss: 2.6523 - CRPS_score_val: 0.0127
# Epoch 65/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6469
# Epoch 00065: CRPS_score_val improved from 0.01271 to 0.01270, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 80us/sample - loss: 2.6467 - CRPS_score_val: 0.0127
# Epoch 66/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6501
# Epoch 00066: CRPS_score_val did not improve from 0.01270
# 18537/18537 [==============================] - 2s 81us/sample - loss: 2.6505 - CRPS_score_val: 0.0127
# Epoch 67/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6419
# Epoch 00067: CRPS_score_val improved from 0.01270 to 0.01269, saving model to best_model.h5
# 18537/18537 [==============================] - 2s 83us/sample - loss: 2.6419 - CRPS_score_val: 0.0127
# Epoch 68/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6387
# Epoch 00068: CRPS_score_val improved from 0.01269 to 0.01269, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 64us/sample - loss: 2.6377 - CRPS_score_val: 0.0127
# Epoch 69/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6474
# Epoch 00069: CRPS_score_val did not improve from 0.01269
# 18537/18537 [==============================] - 1s 59us/sample - loss: 2.6466 - CRPS_score_val: 0.0127
# Epoch 70/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6458
# Epoch 00070: CRPS_score_val did not improve from 0.01269
# 18537/18537 [==============================] - 1s 61us/sample - loss: 2.6441 - CRPS_score_val: 0.0127
# Epoch 71/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6414
# Epoch 00071: CRPS_score_val did not improve from 0.01269
# 18537/18537 [==============================] - 1s 59us/sample - loss: 2.6420 - CRPS_score_val: 0.0127
# Epoch 72/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6375
# Epoch 00072: CRPS_score_val did not improve from 0.01269
# 18537/18537 [==============================] - 1s 60us/sample - loss: 2.6343 - CRPS_score_val: 0.0127
# Epoch 73/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6346
# Epoch 00073: CRPS_score_val did not improve from 0.01269
# 18537/18537 [==============================] - 1s 58us/sample - loss: 2.6356 - CRPS_score_val: 0.0127
# Epoch 74/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6358
# Epoch 00074: CRPS_score_val did not improve from 0.01269
# 18537/18537 [==============================] - 1s 59us/sample - loss: 2.6381 - CRPS_score_val: 0.0127
# Epoch 75/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6316
# Epoch 00075: CRPS_score_val did not improve from 0.01269
# 18537/18537 [==============================] - 1s 60us/sample - loss: 2.6317 - CRPS_score_val: 0.0127
# Epoch 76/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6288
# Epoch 00076: CRPS_score_val did not improve from 0.01269
# 18537/18537 [==============================] - 1s 59us/sample - loss: 2.6290 - CRPS_score_val: 0.0127
# Epoch 77/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6240
# Epoch 00077: CRPS_score_val improved from 0.01269 to 0.01268, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 61us/sample - loss: 2.6264 - CRPS_score_val: 0.0127
# Epoch 78/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6296
# Epoch 00078: CRPS_score_val improved from 0.01268 to 0.01268, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 62us/sample - loss: 2.6287 - CRPS_score_val: 0.0127
# Epoch 79/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6261
# Epoch 00079: CRPS_score_val improved from 0.01268 to 0.01268, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 63us/sample - loss: 2.6269 - CRPS_score_val: 0.0127
# Epoch 80/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6226
# Epoch 00080: CRPS_score_val improved from 0.01268 to 0.01268, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 62us/sample - loss: 2.6226 - CRPS_score_val: 0.0127
# Epoch 81/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6287
# Epoch 00081: CRPS_score_val did not improve from 0.01268
# 18537/18537 [==============================] - 1s 62us/sample - loss: 2.6265 - CRPS_score_val: 0.0127
# Epoch 82/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6220
# Epoch 00082: CRPS_score_val did not improve from 0.01268
# 18537/18537 [==============================] - 1s 59us/sample - loss: 2.6208 - CRPS_score_val: 0.0127
# Epoch 83/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6195
# Epoch 00083: CRPS_score_val did not improve from 0.01268
# 18537/18537 [==============================] - 1s 61us/sample - loss: 2.6177 - CRPS_score_val: 0.0127
# Epoch 84/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6162
# Epoch 00084: CRPS_score_val did not improve from 0.01268
# 18537/18537 [==============================] - 1s 60us/sample - loss: 2.6186 - CRPS_score_val: 0.0127
# Epoch 85/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6221
# Epoch 00085: CRPS_score_val did not improve from 0.01268
# 18537/18537 [==============================] - 1s 58us/sample - loss: 2.6212 - CRPS_score_val: 0.0127
# Epoch 86/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6112
# Epoch 00086: CRPS_score_val improved from 0.01268 to 0.01268, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 60us/sample - loss: 2.6131 - CRPS_score_val: 0.0127
# Epoch 87/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6103
# Epoch 00087: CRPS_score_val did not improve from 0.01268
# 18537/18537 [==============================] - 1s 59us/sample - loss: 2.6108 - CRPS_score_val: 0.0127
# Epoch 88/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6139
# Epoch 00088: CRPS_score_val improved from 0.01268 to 0.01267, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 60us/sample - loss: 2.6110 - CRPS_score_val: 0.0127
# Epoch 89/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6140
# Epoch 00089: CRPS_score_val did not improve from 0.01267
# 18537/18537 [==============================] - 1s 59us/sample - loss: 2.6147 - CRPS_score_val: 0.0127
# Epoch 90/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6101
# Epoch 00090: CRPS_score_val improved from 0.01267 to 0.01267, saving model to best_model.h5
# ...
# Epoch 00026: CRPS_score_val improved from 0.01277 to 0.01275, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 65us/sample - loss: 2.7319 - CRPS_score_val: 0.0128
# Epoch 27/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.7337
# Epoch 00027: CRPS_score_val improved from 0.01275 to 0.01274, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 69us/sample - loss: 2.7336 - CRPS_score_val: 0.0127
# Epoch 28/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.7288
# Epoch 00028: CRPS_score_val improved from 0.01274 to 0.01273, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 65us/sample - loss: 2.7307 - CRPS_score_val: 0.0127
# Epoch 29/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.7306
# Epoch 00029: CRPS_score_val improved from 0.01273 to 0.01272, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 66us/sample - loss: 2.7302 - CRPS_score_val: 0.0127
# Epoch 30/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.7214
# Epoch 00030: CRPS_score_val improved from 0.01272 to 0.01272, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 68us/sample - loss: 2.7230 - CRPS_score_val: 0.0127
# Epoch 31/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.7211
# Epoch 00031: CRPS_score_val improved from 0.01272 to 0.01271, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 66us/sample - loss: 2.7242 - CRPS_score_val: 0.0127
# Epoch 32/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.7199
# Epoch 00032: CRPS_score_val improved from 0.01271 to 0.01270, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 65us/sample - loss: 2.7188 - CRPS_score_val: 0.0127
# Epoch 33/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.7123
# Epoch 00033: CRPS_score_val improved from 0.01270 to 0.01270, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 65us/sample - loss: 2.7128 - CRPS_score_val: 0.0127
# Epoch 34/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.7128
# Epoch 00034: CRPS_score_val did not improve from 0.01270
# 18537/18537 [==============================] - 1s 65us/sample - loss: 2.7124 - CRPS_score_val: 0.0127
# Epoch 35/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.7097
# Epoch 00035: CRPS_score_val improved from 0.01270 to 0.01269, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 66us/sample - loss: 2.7099 - CRPS_score_val: 0.0127
# Epoch 36/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.7107
# Epoch 00036: CRPS_score_val improved from 0.01269 to 0.01268, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 65us/sample - loss: 2.7113 - CRPS_score_val: 0.0127
# Epoch 37/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.7082
# Epoch 00037: CRPS_score_val improved from 0.01268 to 0.01267, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 65us/sample - loss: 2.7065 - CRPS_score_val: 0.0127
# Epoch 38/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.7093
# Epoch 00038: CRPS_score_val improved from 0.01267 to 0.01266, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 65us/sample - loss: 2.7071 - CRPS_score_val: 0.0127
# Epoch 39/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6985
# Epoch 00039: CRPS_score_val improved from 0.01266 to 0.01265, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 65us/sample - loss: 2.6981 - CRPS_score_val: 0.0127
# Epoch 40/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.7006
# Epoch 00040: CRPS_score_val did not improve from 0.01265
# 18537/18537 [==============================] - 1s 64us/sample - loss: 2.6993 - CRPS_score_val: 0.0127
# Epoch 41/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6989
# Epoch 00041: CRPS_score_val improved from 0.01265 to 0.01264, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 66us/sample - loss: 2.6980 - CRPS_score_val: 0.0126
# Epoch 42/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.7000
# Epoch 00042: CRPS_score_val did not improve from 0.01264
# 18537/18537 [==============================] - 1s 63us/sample - loss: 2.7011 - CRPS_score_val: 0.0127
# Epoch 43/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6976
# Epoch 00043: CRPS_score_val improved from 0.01264 to 0.01264, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 67us/sample - loss: 2.6966 - CRPS_score_val: 0.0126
# Epoch 44/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6933
# Epoch 00044: CRPS_score_val improved from 0.01264 to 0.01264, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 68us/sample - loss: 2.6932 - CRPS_score_val: 0.0126
# Epoch 45/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6887
# Epoch 00045: CRPS_score_val improved from 0.01264 to 0.01263, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 68us/sample - loss: 2.6888 - CRPS_score_val: 0.0126
# Epoch 46/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6839
# Epoch 00046: CRPS_score_val improved from 0.01263 to 0.01263, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 66us/sample - loss: 2.6876 - CRPS_score_val: 0.0126
# Epoch 47/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6804
# Epoch 00047: CRPS_score_val improved from 0.01263 to 0.01262, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 67us/sample - loss: 2.6849 - CRPS_score_val: 0.0126
# Epoch 48/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6806
# Epoch 00048: CRPS_score_val did not improve from 0.01262
# 18537/18537 [==============================] - 1s 64us/sample - loss: 2.6831 - CRPS_score_val: 0.0126
# Epoch 49/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6802
# Epoch 00049: CRPS_score_val improved from 0.01262 to 0.01261, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 66us/sample - loss: 2.6805 - CRPS_score_val: 0.0126
# Epoch 50/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6794
# Epoch 00050: CRPS_score_val improved from 0.01261 to 0.01261, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 66us/sample - loss: 2.6785 - CRPS_score_val: 0.0126
# Epoch 51/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6767
# Epoch 00051: CRPS_score_val did not improve from 0.01261
# 18537/18537 [==============================] - 1s 63us/sample - loss: 2.6795 - CRPS_score_val: 0.0126
# Epoch 52/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6755
# Epoch 00052: CRPS_score_val did not improve from 0.01261
# 18537/18537 [==============================] - 1s 63us/sample - loss: 2.6760 - CRPS_score_val: 0.0126
# Epoch 53/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6746
# Epoch 00053: CRPS_score_val did not improve from 0.01261
# 18537/18537 [==============================] - 1s 64us/sample - loss: 2.6746 - CRPS_score_val: 0.0126
# Epoch 54/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6699
# Epoch 00054: CRPS_score_val did not improve from 0.01261
# 18537/18537 [==============================] - 1s 64us/sample - loss: 2.6721 - CRPS_score_val: 0.0126
# Epoch 55/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6686
# Epoch 00055: CRPS_score_val improved from 0.01261 to 0.01260, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 70us/sample - loss: 2.6685 - CRPS_score_val: 0.0126
# Epoch 56/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6673
# Epoch 00056: CRPS_score_val improved from 0.01260 to 0.01260, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 68us/sample - loss: 2.6682 - CRPS_score_val: 0.0126
# Epoch 57/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6707
# Epoch 00057: CRPS_score_val improved from 0.01260 to 0.01259, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 68us/sample - loss: 2.6719 - CRPS_score_val: 0.0126
# Epoch 58/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6695
# Epoch 00058: CRPS_score_val improved from 0.01259 to 0.01258, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 67us/sample - loss: 2.6694 - CRPS_score_val: 0.0126
# Epoch 59/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6665
# Epoch 00059: CRPS_score_val did not improve from 0.01258
# 18537/18537 [==============================] - 1s 66us/sample - loss: 2.6664 - CRPS_score_val: 0.0126
# Epoch 60/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6571
# Epoch 00060: CRPS_score_val did not improve from 0.01258
# 18537/18537 [==============================] - 1s 64us/sample - loss: 2.6571 - CRPS_score_val: 0.0126
# Epoch 61/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6637
# Epoch 00061: CRPS_score_val improved from 0.01258 to 0.01257, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 67us/sample - loss: 2.6632 - CRPS_score_val: 0.0126
# Epoch 62/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6563
# Epoch 00062: CRPS_score_val did not improve from 0.01257
# 18537/18537 [==============================] - 1s 65us/sample - loss: 2.6572 - CRPS_score_val: 0.0126
# Epoch 63/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6609
# Epoch 00063: CRPS_score_val improved from 0.01257 to 0.01257, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 66us/sample - loss: 2.6605 - CRPS_score_val: 0.0126
# Epoch 64/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6572
# Epoch 00064: CRPS_score_val improved from 0.01257 to 0.01256, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 66us/sample - loss: 2.6595 - CRPS_score_val: 0.0126
# Epoch 65/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6538
# Epoch 00065: CRPS_score_val improved from 0.01256 to 0.01256, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 67us/sample - loss: 2.6528 - CRPS_score_val: 0.0126
# Epoch 66/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6496
# Epoch 00066: CRPS_score_val improved from 0.01256 to 0.01256, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 66us/sample - loss: 2.6498 - CRPS_score_val: 0.0126
# Epoch 67/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6513
# Epoch 00067: CRPS_score_val did not improve from 0.01256
# 18537/18537 [==============================] - 1s 64us/sample - loss: 2.6509 - CRPS_score_val: 0.0126
# Epoch 68/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6473
# Epoch 00068: CRPS_score_val did not improve from 0.01256
# 18537/18537 [==============================] - 1s 65us/sample - loss: 2.6466 - CRPS_score_val: 0.0126
# Epoch 69/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6473
# Epoch 00069: CRPS_score_val improved from 0.01256 to 0.01256, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 66us/sample - loss: 2.6480 - CRPS_score_val: 0.0126
# Epoch 70/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6460
# Epoch 00070: CRPS_score_val improved from 0.01256 to 0.01255, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 70us/sample - loss: 2.6445 - CRPS_score_val: 0.0125
# Epoch 71/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6462
# Epoch 00071: CRPS_score_val did not improve from 0.01255
# 18537/18537 [==============================] - 1s 67us/sample - loss: 2.6464 - CRPS_score_val: 0.0126
# Epoch 72/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6476
# Epoch 00072: CRPS_score_val did not improve from 0.01255
# 18537/18537 [==============================] - 1s 66us/sample - loss: 2.6480 - CRPS_score_val: 0.0126
# Epoch 73/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6429
# Epoch 00073: CRPS_score_val did not improve from 0.01255
# 18537/18537 [==============================] - 1s 63us/sample - loss: 2.6449 - CRPS_score_val: 0.0125
# Epoch 74/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6397
# Epoch 00074: CRPS_score_val did not improve from 0.01255
# 18537/18537 [==============================] - 1s 64us/sample - loss: 2.6412 - CRPS_score_val: 0.0126
# Epoch 75/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6448
# Epoch 00075: CRPS_score_val improved from 0.01255 to 0.01253, saving model to best_model.h5
# 18537/18537 [==============================] - 1s 66us/sample - loss: 2.6443 - CRPS_score_val: 0.0125
# Epoch 76/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6382
# Epoch 00076: CRPS_score_val improved from 0.01253 to 0.01252, saving model to best_model.h5
# 18537/18537 [==============================] - 2s 82us/sample - loss: 2.6384 - CRPS_score_val: 0.0125
# Epoch 77/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6315
# Epoch 00077: CRPS_score_val did not improve from 0.01252
# 18537/18537 [==============================] - 1s 70us/sample - loss: 2.6318 - CRPS_score_val: 0.0125
# Epoch 78/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6405
# Epoch 00078: CRPS_score_val did not improve from 0.01252
# 18537/18537 [==============================] - 1s 68us/sample - loss: 2.6402 - CRPS_score_val: 0.0125
# Epoch 79/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6316
# Epoch 00079: CRPS_score_val did not improve from 0.01252
# 18537/18537 [==============================] - 1s 66us/sample - loss: 2.6315 - CRPS_score_val: 0.0125
# Epoch 80/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6317
# Epoch 00080: CRPS_score_val did not improve from 0.01252
# 18537/18537 [==============================] - 1s 65us/sample - loss: 2.6315 - CRPS_score_val: 0.0125
# Epoch 81/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6238
# Epoch 00081: CRPS_score_val did not improve from 0.01252
# 18537/18537 [==============================] - 1s 64us/sample - loss: 2.6247 - CRPS_score_val: 0.0125
# Epoch 82/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6290
# Epoch 00082: CRPS_score_val did not improve from 0.01252
# 18537/18537 [==============================] - 1s 65us/sample - loss: 2.6276 - CRPS_score_val: 0.0125
# Epoch 83/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6307
# Epoch 00083: CRPS_score_val did not improve from 0.01252
# 18537/18537 [==============================] - 1s 67us/sample - loss: 2.6301 - CRPS_score_val: 0.0125
# Epoch 84/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6259
# Epoch 00084: CRPS_score_val did not improve from 0.01252
# 18537/18537 [==============================] - 1s 65us/sample - loss: 2.6228 - CRPS_score_val: 0.0125
# Epoch 85/100
# 17408/18537 [===========================>..] - ETA: 0s - loss: 2.6253
# Epoch 00085: CRPS_score_val did not improve from 0.01252
# 18537/18537 [==============================] - 1s 63us/sample - loss: 2.6240 - CRPS_score_val: 0.0125
# Epoch 86/100
# 18432/18537 [============================>.] - ETA: 0s - loss: 2.6258Restoring model weights from the end of the best epoch.
#
# Epoch 00086: CRPS_score_val did not improve from 0.01252
# 18537/18537 [==============================] - 2s 116us/sample - loss: 2.6259 - CRPS_score_val: 0.0125
# Epoch 00086: early stopping
# the 5 fold crps is 0.012524

# %%
print("mean crps is %f" % np.mean(crps_csv))
# Out:
# mean crps is 0.012682

# %%
print(crps_csv)
# Out:
# [0.01276, 0.012664, 0.012623, 0.012491, 0.012913, 0.012374, 0.013009, 0.012251, 0.013213, 0.012524]

# %% [markdown]
# <a id="6"></a> <br>
# # Submission

# %%
# %%time
env = nflrush.make_env()
iter_test = env.iter_test()

def predict(x_te):
    model_num = len(models)
    for k,m in enumerate(models):
        if k==0:
            y_pred = m.predict(x_te,batch_size=1024)
        else:
            y_pred+=m.predict(x_te,batch_size=1024)
    y_pred = y_pred / model_num
    return y_pred

for (test_df, sample_prediction_df) in iter_test:
    basetable = createFeatures(preprocess(test_df), deploy=True)
    basetable.drop(['GameId','PlayId'], axis=1, inplace=True)
    scaled_basetable = scaler.transform(basetable)
    # scaled_basetable = pca.transform(basetable)
    y_pred = predict(scaled_basetable)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1).tolist()[0]
    # print(y_pred)

    preds_df = pd.DataFrame(data=[y_pred], columns=sample_prediction_df.columns)
    env.predict(preds_df)

env.write_submission_file()
# Out:
# Your submission file has been saved!  Once you `Commit` your Notebook and it finishes running, you can submit the file to the competition from the Notebook Viewer `Output` tab.
# CPU times: user 31min 40s, sys: 9.38 s, total: 31min 50s
# Wall time: 31min 15s
